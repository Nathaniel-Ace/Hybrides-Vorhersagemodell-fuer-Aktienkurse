# %%
# %run ../src/baseline_models.py
# Out:
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# === Basismodell für NVDA ===
# Naives Modell:    RMSE=6.9963, MAE=4.9316, MAPE=5.45%, R²=0.9686, Hit-Rate=52.3%, Sharpe=0.2093
# ...

# %% [markdown]
# ## Beobachtungen:
#
# Das naive Modell (Vorhersage = letzter bekannter Preis) funktioniert überraschend gut:
#
# - Sehr hohe R²-Werte (>0.95) bei NVDA, GOOG und MSFT → die Preisbewegungen sind kurzfristig sehr träge und gut vorhersehbar.
#
# - MAPE liegt sehr niedrig (2–5%) → Fehler in relativen Prozenten sind klein.
#
# - Hit-Raten (~45–52%) sind jedoch nur leicht besser als Zufall → Richtungsvorhersagen bleiben schwierig.
#
# Das ARIMA-Modell (1,1,1) hingegen:
#
# - Versagt deutlich: extrem hohe Fehlerwerte (RMSE und MAE), negative R²-Werte → Modell erklärt weniger als keine Varianz, schlechter als ein simpler Durchschnitt.
#
# - Sehr schlechte Hit-Raten (nur 9–36%) und geringe bis negative Sharpe Ratios.
#
# Visuelle Beobachtung:
#
# - Naive Prognosen (rote Punkte) liegen meist gut auf den tatsächlichen Testdaten.
#
# - ARIMA-Prognosen (grüne Linie) sind konstant und verpassen jede Marktentwicklung komplett.

# %%
# %run ../src/SARIMAX.py
# Out:
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# NVDA – SARIMAX Metriken:
#   RMSE       = 66.1499
#   MAE        = 54.0696
#   MAPE       = 52.27%
#   R²         = -1.8087
#   Sharpe     = 0.1317
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# ...

# %% [markdown]
# ## Beobachtungen:
#
# SARIMAX-Modelle liefern insgesamt sehr schlechte Prognosen:
#
# - R²-Werte sind bei allen drei Aktien (NVDA, GOOG, MSFT) stark negativ (zwischen -1.8 und -2.3) → die Modelle sind schlechter als der Mittelwert.
#
# - RMSE und MAE sind extrem hoch → große durchschnittliche Abweichungen von den echten Kursen.
#
# - MAPE-Werte zwischen 17% und 52% deuten auf sehr ungenaue relative Vorhersagen hin.
#
# - Sharpe Ratios sind sehr niedrig (~0.07–0.13) → die Vorhersagen wären kaum profitabel für eine Handelsstrategie.
#
# Visuelle Analyse:
#
# - Die Forecast-Linie (blau) ist bei allen Aktien sehr flach und reagiert nicht auf Marktbewegungen.
#
# - Besonders bei NVDA und MSFT sieht man, dass SARIMAX weder starke Anstiege noch Abfälle korrekt abbilden kann.
