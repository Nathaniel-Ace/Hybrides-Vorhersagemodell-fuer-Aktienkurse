# %% [markdown]
# # GARCH + XGBoost
# ## zusätzlliche Features: RSI
#
# Zeitraum: 1.1.2015 bis 6.2.2025
#
# GTD: "NVIDIA stock", "sell NVIDIA stock", "buy NVIDIA stock" (alle drei Spalten)
#
# Google Trends waren ursprünglich monatlich --> wurden auf wöchentliche Werte interpoliert.

# %%
# %run ../src/GARCH_XGBoost_RSI.py
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: X_train=(120, 12), X_test=(119, 12)
# Fold 1: RMSE_Returns=0.0691, RMSE_Prices=0.3598
# Fold 2: X_train=(249, 12), X_test=(119, 12)
# Fold 2: RMSE_Returns=0.0619, RMSE_Prices=1.2209
# Fold 3: X_train=(378, 12), X_test=(119, 12)
# Fold 3: RMSE_Returns=0.0651, RMSE_Prices=5.7742
#
# --- Durchschnitt über alle Folds ---
# Log-Renditen RMSE: 0.06539389740972627
# Aktienkurse RMSE: 2.451617187004565

# %% [markdown]
# # GARCH + XGBoost
# ## zusätzlliche Features: RSI & GTD (z.B. "Nvidia stock")
#
# Zeitraum: 1.1.2015 bis 6.2.2025
#
# GTD: "NVIDIA stock", "sell NVIDIA stock", "buy NVIDIA stock" (alle drei Spalten)
#
# Google Trends waren ursprünglich monatlich --> wurden auf wöchentliche Werte interpoliert.

# %%
# %run ../src/GARCH_XGBoost_RSI_GTD.py
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: X_train=(120, 15), X_test=(118, 15)
# Fold 1: RMSE_Returns=0.0662, RMSE_Prices=0.3469
# Fold 2: X_train=(248, 15), X_test=(118, 15)
# Fold 2: RMSE_Returns=0.0613, RMSE_Prices=1.2063
# Fold 3: X_train=(376, 15), X_test=(118, 15)
# Fold 3: RMSE_Returns=0.0642, RMSE_Prices=5.4279
#
# --- Durchschnitt über alle Folds ---
# Log-Renditen RMSE: 0.06387538912629301
# Aktienkurse RMSE: 2.3270516198813174

# %% [markdown]
# # GARCH + XGBoost
# ## zusätzlliche Features: RSI Trend_Average & Trend_Smoothed
#
# Zeitraum: 1.1.2015 bis 6.2.2025
#
# Google Trends waren ursprünglich monatlich --> wurden auf wöchentliche Werte interpoliert.

# %%
# %run ../src/GARCH_XGBoost_RSI_GTD.py
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: X_train=(120, 15), X_test=(118, 15)
# Fold 1: RMSE_Returns=0.0662, RMSE_Prices=0.3469
# Fold 2: X_train=(248, 15), X_test=(118, 15)
# Fold 2: RMSE_Returns=0.0613, RMSE_Prices=1.2063
# Fold 3: X_train=(376, 15), X_test=(118, 15)
# Fold 3: RMSE_Returns=0.0642, RMSE_Prices=5.4279
#
# --- Durchschnitt über alle Folds ---
# Log-Renditen RMSE: 0.06387538912629301
# Aktienkurse RMSE: 2.3270516198813174

# %% [markdown]
# # GARCH + XGBoost
# ## zusätzlliche Features: RSI
#
# Zeitraum: 01.01.2015 bis 24.04.2025
#
# GTD: "NVIDIA stock", "sell NVIDIA stock", "buy NVIDIA stock" (alle drei Spalten)

# %%
# %run ../src/GARCH_XGBoost_RSI.py
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: X_train=(122, 12), X_test=(121, 12)
# Fold 1: RMSE_Returns=0.0691, RMSE_Prices=0.3612
# Fold 2: X_train=(253, 12), X_test=(121, 12)
# Fold 2: RMSE_Returns=0.0625, RMSE_Prices=1.2260
# Fold 3: X_train=(384, 12), X_test=(121, 12)
# Fold 3: RMSE_Returns=0.0634, RMSE_Prices=5.8687
#
# --- Durchschnitt über alle Folds ---
# Log-Renditen RMSE: 0.0650255840941358
# Aktienkurse RMSE: 2.4852885642413773

# %% [markdown]
# # GARCH + XGBoost
# ## zusätzlliche Features: RSI & GTD
#
# Zeitraum: 29.12.2019 bis 14.04.2025
#
# GTD: "NVIDIA stock", "sell NVIDIA stock", "buy NVIDIA stock" (alle drei Spalten)

# %%
# %run ../src/GARCH_XGBoost_RSI_GTD.py
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: X_train=(121, 15), X_test=(121, 15)
# Fold 1: RMSE_Returns=0.0690, RMSE_Prices=0.3671
# Fold 2: X_train=(252, 15), X_test=(121, 15)
# Fold 2: RMSE_Returns=0.0622, RMSE_Prices=1.1833
# Fold 3: X_train=(383, 15), X_test=(121, 15)
# Fold 3: RMSE_Returns=0.0632, RMSE_Prices=5.7468
#
# --- Durchschnitt über alle Folds ---
# Log-Renditen RMSE: 0.06481624115606693
# Aktienkurse RMSE: 2.4324198986737513

# %% [markdown]
# # GARCH + XGBoost
# ## zusätzlliche Features: RSI Trend_Average & Trend_Smoothed
#
# Zeitraum: 29.12.2019 bis 14.04.2025

# %%
# %run ../src/GARCH_XGBoost_RSI_GTD.py
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: X_train=(121, 15), X_test=(121, 15)
# Fold 1: RMSE_Returns=0.0690, RMSE_Prices=0.3671
# Fold 2: X_train=(252, 15), X_test=(121, 15)
# Fold 2: RMSE_Returns=0.0622, RMSE_Prices=1.1833
# Fold 3: X_train=(383, 15), X_test=(121, 15)
# Fold 3: RMSE_Returns=0.0632, RMSE_Prices=5.7468
#
# --- Durchschnitt über alle Folds ---
# Log-Renditen RMSE: 0.06481624115606693
# Aktienkurse RMSE: 2.4324198986737513
