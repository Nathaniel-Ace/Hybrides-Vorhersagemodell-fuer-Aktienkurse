# %%
# %run ../src/baseline_models.py
# Out:
# NVDA Aktienkurse (head):
#                Close      High       Low      Open      Volume
# Date
# 2015-01-01  0.459382  0.486744  0.457942  0.483144   831204000
# 2015-01-08  0.473783  0.485784  0.464423  0.464663  1076032000
# 2015-01-15  0.487224  0.488424  0.468263  0.477143   655532000
# 2015-01-22  0.463463  0.498024  0.463223  0.488184  1044044000
# 2015-01-29  0.483864  0.489384  0.454582  0.463703  1158128000
# GOOG Aktienkurse (head):
#                 Close       High        Low       Open     Volume
# Date
# 2015-01-01  24.896944  26.395928  24.824901  26.283639  169447946
# 2015-01-08  24.885517  25.086738  24.224214  24.742425  247158716
# 2015-01-15  25.738600  25.800209  24.730995  25.119032  190297030
# 2015-01-22  25.339134  26.937487  25.339134  25.909513  201804538
# 2015-01-29  25.973110  26.823213  24.901911  25.388820  326897039
# MSFT Aktienkurse (head):
#                 Close       High        Low       Open     Volume
# Date
# 2015-01-01  39.617931  40.637730  38.983772  39.986431  133149800
# 2015-01-08  39.386547  41.057648  39.095176  40.063558  142231500
# 2015-01-15  39.352283  39.977878  38.709552  39.609379  143689100
# 2015-01-22  35.298794  40.612039  35.273086  39.746495  358306200
# 2015-01-29  35.855816  36.172896  34.476086  35.075969  285639900
#
# === Basismodell für NVDA ===
# Naives Modell: RMSE = 6.9252
# ARIMA(1,1,1): RMSE = 71.5128
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# === Basismodell für GOOG ===
# Naives Modell: RMSE = 5.3200
# ARIMA(1,1,1): RMSE = 59.3416
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# === Basismodell für MSFT ===
# Naives Modell: RMSE = 9.9309
# ARIMA(1,1,1): RMSE = 125.2251
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-THU will be used.
#   self._init_dates(dates, freq)
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# === Zusammenfassung Basismodelle ===
#   Ticker  RMSE_Naive  RMSE_ARIMA
# 0   NVDA    6.925165   71.512777
# 1   GOOG    5.319979   59.341639
# 2   MSFT    9.930892  125.225109

# %%
# %run ../src/lstm.py
# Out:
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Fold 1 RMSE: 0.8197
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Fold 2 RMSE: 2.4527
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000255ADD29D00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000255ADD29D00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Fold 3 RMSE: 16.7671
#
# Durchschnittlicher RMSE über 3 Folds: 6.6798

# %%
# %run ../src/lstm.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Fold 1 RMSE: 0.9679
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Fold 2 RMSE: 2.7628
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Fold 3 RMSE: 21.0918
#
# Durchschnittlicher RMSE über 3 Folds: 8.2741

# %%
# %run ../src/XGBoost.py
# Out:
# Fold 1: X_train=(125, 10), y_train=(125,), X_test=(122, 10), y_test=(122,)
# Fold 1 RMSE: 1.4428
# Fold 2: X_train=(257, 10), y_train=(257,), X_test=(122, 10), y_test=(122,)
# Fold 2 RMSE: 13.4372
# Fold 3: X_train=(389, 10), y_train=(389,), X_test=(122, 10), y_test=(122,)
# Fold 3 RMSE: 63.6846
#
# Durchschnittlicher RMSE über 3 Folds: 26.1882

# %% [markdown]
# # 1. Hybrid-Modell: GARCH + XGBoost

# %%
# %run ../src/GARCH_XGBoost.py
# Out:
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\.venv\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00399. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# X_train shape: (414, 11) y_train shape: (414,)
# X_test shape: (96, 11) y_test shape: (96,)
# RMSE für das Hybrid-Modell (XGBoost mit GARCH Volatilität): 0.0723

# %%
# %run ../src/GARCH_XGBoost.py
# Out:
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.002
# Vol Model:                      GARCH   Log-Likelihood:               -403.144
# Distribution:                  Normal   AIC:                           812.288
# Method:            Maximum Likelihood   BIC:                           824.437
#                                         No. Observations:                  424
# Date:                Fri, Mar 21 2025   Df Residuals:                      424
# Time:                        10:24:36   Df Model:                            0
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.0665  3.873e-02      1.717  8.592e-02 [-9.397e-03,  0.142]
# alpha[1]       0.0957  5.291e-02      1.809  7.045e-02 [-7.987e-03,  0.199]
# beta[1]        0.7443      0.115      6.482  9.050e-11    [  0.519,  0.969]
# ===========================================================================
#
# Covariance estimator: robust
# X_train shape: (414, 11) y_train shape: (414,)
# X_test shape: (96, 11) y_test shape: (96,)
# RMSE für das Hybrid-Modell (XGBoost mit GARCH Volatilität): 0.0723

# %%
# %run ../src/GARCH_XGBoost.py
# Out:
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.002
# Vol Model:                      GARCH   Log-Likelihood:               -403.144
# Distribution:                  Normal   AIC:                           812.288
# Method:            Maximum Likelihood   BIC:                           824.437
#                                         No. Observations:                  424
# Date:                Fri, Mar 21 2025   Df Residuals:                      424
# Time:                        10:32:22   Df Model:                            0
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.0665  3.873e-02      1.717  8.592e-02 [-9.397e-03,  0.142]
# alpha[1]       0.0957  5.291e-02      1.809  7.045e-02 [-7.987e-03,  0.199]
# beta[1]        0.7443      0.115      6.482  9.050e-11    [  0.519,  0.969]
# ===========================================================================
#
# Covariance estimator: robust
# X_train shape: (414, 11) y_train shape: (414,)
# X_test shape: (96, 11) y_test shape: (96,)
# RMSE auf Renditen: 0.0723

# %%
# %run ../src/GARCH_XGBoost.py
# Out:
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.002
# Vol Model:                      GARCH   Log-Likelihood:               -403.144
# Distribution:                  Normal   AIC:                           812.288
# Method:            Maximum Likelihood   BIC:                           824.437
#                                         No. Observations:                  424
# Date:                Fri, Mar 21 2025   Df Residuals:                      424
# Time:                        10:37:12   Df Model:                            0
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.0665  3.873e-02      1.717  8.592e-02 [-9.397e-03,  0.142]
# alpha[1]       0.0957  5.291e-02      1.809  7.045e-02 [-7.987e-03,  0.199]
# beta[1]        0.7443      0.115      6.482  9.050e-11    [  0.519,  0.969]
# ===========================================================================
#
# Covariance estimator: robust
# X_train shape: (414, 11) y_train shape: (414,)
# X_test shape: (96, 11) y_test shape: (96,)
# RMSE auf logarithmische Renditen: 0.0723
# RMSE auf Aktienkurs-Basis: 7.3111
