# %% [markdown]
# # LSTM-Modell

# %%
# %run ../src/lstm.py
# Out:
# Fold 1 – RMSE=5.5209, MAE=4.0601, MAPE=3.52%, R²=0.9500, Hit-Rate=59.3%, Sharpe=1.1861
# Fold 2 – RMSE=20.8867, MAE=15.8746, MAPE=6.24%, R²=0.7325, Hit-Rate=56.1%, Sharpe=0.4325
# Fold 3 – RMSE=30.5302, MAE=26.0512, MAPE=6.86%, R²=0.7616, Hit-Rate=49.6%, Sharpe=0.5088
#
# === Durchschnitt aller Folds ===
# RMSE:     18.9792
# MAE:      15.3287
# MAPE:     5.5406%
# R²:       0.8147
# Hit-Rate: 55.0136%
# Sharpe:   0.7091

# %% [markdown]
# # XGBoost-Modell

# %%
# %run ../src/XGBoost.py
# Out:
# Fold 1: X_train=(127, 10), y_train=(127,), X_test=(124, 10), y_test=(124,)
# Fold 1 – RMSE=50.2827, MAE=43.7977, MAPE=36.58%, R²=-3.1441, Hit-Rate=0.0%, Sharpe=nan
#
# Fold 2: X_train=(261, 10), y_train=(261,), X_test=(124, 10), y_test=(124,)
# Fold 2 – RMSE=108.3364, MAE=100.2796, MAPE=38.18%, R²=-6.1975, Hit-Rate=3.3%, Sharpe=-0.0254
#
# Fold 3: X_train=(395, 10), y_train=(395,), X_test=(124, 10), y_test=(124,)
# Fold 3 – RMSE=82.6715, MAE=67.3538, MAPE=16.61%, R²=-0.7484, Hit-Rate=27.6%, Sharpe=0.1449
#
# === Durchschnitt über alle Folds ===
# RMSE:       80.4302
# MAE:        70.4770
# MAPE:       30.4576%
# R²:         -3.3633
# Hit-Rate:   10.2981%
# Sharpe:     0.0598

# %% [markdown]
# # GARCH + LSTM Hybridmodell

# %%
# %run ../src/GARCH_LSTM2.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Fold 1 fertig.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Fold 2 fertig.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Fold 3 fertig.
# === Log-Returns (Ø über 3 Folds) ===
# RMSE: 0.0311, MAE: 0.0240, MAPE: 171.7000%, R²: -0.0140, Hit: 71.8157%, Sharpe: 0.1008
# === Close-Preise (Ø über 3 Folds) ===
# RMSE: 7.6404, MAE: 5.8439, MAPE: 2.4218%, R²: 0.9673, Hit: 49.3225%, Sharpe: 0.1578

# %% [markdown]
# # GARCH + LSTM Hybridmodell
# ## zusätzliches Feature: RSI

# %%
# %run ../src/GARCH_LSTM_RSI2.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.0286
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.0005, 'batch_size': 16}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Fold 1:
#   Returns → RMSE=0.0292, MAE=0.0214, MAPE=283.9257%, R2=0.2088, Hit-Rate=77.5000%, Sharpe=-0.1331
#   Prices  → RMSE=3.6205, MAE=2.4994, MAPE=2.1551%, R2=0.9785, Hit-Rate=57.5000%, Sharpe=0.2124
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Fold 2:
#   Returns → RMSE=0.0318, MAE=0.0257, MAPE=230.6777%, R2=0.2129, Hit-Rate=79.1667%, Sharpe=0.0390
#   Prices  → RMSE=8.0502, MAE=6.4864, MAPE=2.5896%, R2=0.9556, Hit-Rate=55.8333%, Sharpe=0.0494
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Fold 3:
#   Returns → RMSE=0.0250, MAE=0.0206, MAPE=188.5191%, R2=0.1410, Hit-Rate=72.5000%, Sharpe=-0.0144
#   Prices  → RMSE=9.2310, MAE=7.5930, MAPE=2.0617%, R2=0.9759, Hit-Rate=60.8333%, Sharpe=0.1642
#
# === Durchschnittliche Metriken: Log-Renditen ===
# RMSE      = 0.0287
# MAE       = 0.0226
# MAPE      = 234.37%
# R²        = 0.1876
# HitRate   = 76.39%
# Sharpe    = -0.0362
#
# === Durchschnittliche Metriken: Preise ===
# RMSE      = 6.9672
# MAE       = 5.5263
# MAPE      = 2.27%
# R²        = 0.9700
# HitRate   = 58.06%
# Sharpe    = 0.1420

# %% [markdown]
# # GARCH + XGBoost Hybridmodell

# %%
# %run ../src/GARCH_XGBoost2.py
# Out:
# Fold 1: RMSE_Returns=0.0363, RMSE_Prices=4.4637
# Fold 2: RMSE_Returns=0.0377, RMSE_Prices=9.5301
# Fold 3: RMSE_Returns=0.0279, RMSE_Prices=10.2567
#
# === Ø Metriken: Log-Renditen ===
# RMSE   = 0.0340
# MAE    = 0.0265
# MAPE   = 263.24%
# R²     = -0.2109
# HitRate= 55.65%
# Sharpe = 0.3812
#
# === Ø Metriken: Close-Preise ===
# RMSE   = 8.0835
# MAE    = 6.2495
# MAPE   = 2.67%
# R²     = 0.9616
# HitRate= 52.03%
# Sharpe = 0.1073

# %% [markdown]
# # GARCH + XGBoost Hybridmodell
# ## zusätzliches Feature: RSI

# %%
# %run ../src/GARCH_XGBoost_RSI.py
# Out:
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: RMSE_Returns=0.0330, RMSE_Prices=4.1109
# Fold 2: RMSE_Returns=0.0340, RMSE_Prices=8.6302
# Fold 3: RMSE_Returns=0.0250, RMSE_Prices=9.1455
#
# === Ø Metriken: Log-Renditen ===
# RMSE    = 0.0307
# MAE     = 0.0243
# MAPE    = 177.56%
# R²      = 0.0760
# HitRate = 63.36%
# Sharpe  = 0.4877
#
# === Ø Metriken: Close-Preise ===
# RMSE    = 7.2955
# MAE     = 5.7848
# MAPE    = 2.43%
# R²      = 0.9659
# HitRate = 53.06%
# Sharpe  = 0.1070

# %% [markdown]
# # GARCH + LSTM Hybridmodell
# ## zusätzliches Feature: RSI & GTD

# %%
# %run ../src/GARCH_LSTM_RSI_GTD.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14', 'Microsoft stock', 'sell Microsoft stock', 'buy Microsoft stock']
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B1468A9120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B1468A9120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
#
# Best CV-RMSE (Log-Renditen): 0.0332
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.0005, 'batch_size': 16}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Fold 1:
#   Returns → RMSE=0.0583, MAE=0.0529, MAPE=1179.72%, R²=-2.1575, Hit-Rate=47.5%, Sharpe=-0.0285
#   Prices  → RMSE=6.8418, MAE=6.0183, MAPE=5.14%, R²=0.9219, Hit-Rate=49.2%, Sharpe=0.1940
#
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Fold 2:
#   Returns → RMSE=0.0686, MAE=0.0614, MAPE=740.23%, R²=-2.6589, Hit-Rate=50.0%, Sharpe=0.0461
#   Prices  → RMSE=16.9669, MAE=15.0756, MAPE=5.91%, R²=0.8058, Hit-Rate=50.8%, Sharpe=0.0527
#
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Fold 3:
#   Returns → RMSE=0.0542, MAE=0.0484, MAPE=657.02%, R²=-3.0830, Hit-Rate=38.3%, Sharpe=-0.0156
#   Prices  → RMSE=19.2918, MAE=17.1655, MAPE=4.70%, R²=0.8996, Hit-Rate=49.2%, Sharpe=0.1610
#
#
# === Durchschnittliche Metriken: Log-Renditen ===
# RMSE    = 0.0604
# MAE     = 0.0542
# MAPE    = 858.99%
# R²      = -2.6332
# HitRate = 45.28%
# Sharpe  = 0.0007
#
# === Durchschnittliche Metriken: Preise ===
# RMSE    = 14.3669
# MAE     = 12.7531
# MAPE    = 5.25%
# R²      = 0.8758
# HitRate = 49.72%
# Sharpe  = 0.1359

# %% [markdown]
# # GARCH + XGBoost Hybridmodell
# ## zusätzliches Feature: RSI & GTD

# %%
# %run ../src/GARCH_XGBoost_RSI_GTD.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14', 'Microsoft stock', 'sell Microsoft stock', 'buy Microsoft stock']
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: X_train=(121, 15), X_test=(121, 15)
# Fold 1:
#   Returns → RMSE=0.0329, MAE=0.0241, MAPE=256.50%, R²=-0.0042, Hit-Rate=28.3%, Sharpe=-0.1255
#   Prices  → RMSE=4.1362, MAE=2.8292, MAPE=2.43%, R²=0.9715, Hit-Rate=48.3%, Sharpe=0.1919
#
# Fold 2: X_train=(252, 15), X_test=(121, 15)
# Fold 2:
#   Returns → RMSE=0.0349, MAE=0.0278, MAPE=144.58%, R²=0.0540, Hit-Rate=65.8%, Sharpe=0.1049
#   Prices  → RMSE=8.8382, MAE=6.9795, MAPE=2.79%, R²=0.9473, Hit-Rate=52.5%, Sharpe=0.0530
#
# Fold 3: X_train=(383, 15), X_test=(121, 15)
# Fold 3:
#   Returns → RMSE=0.0236, MAE=0.0195, MAPE=189.96%, R²=0.2238, Hit-Rate=71.7%, Sharpe=0.0665
#   Prices  → RMSE=8.5469, MAE=7.0570, MAPE=1.95%, R²=0.9803, Hit-Rate=60.0%, Sharpe=0.1637
#
#
# === Durchschnittliche Metriken: Log-Renditen ===
# RMSE    = 0.0305
# MAE     = 0.0238
# MAPE    = 197.01%
# R²      = 0.0912
# HitRate = 55.28%
# Sharpe  = 0.0153
#
# === Durchschnittliche Metriken: Preise ===
# RMSE    = 7.1738
# MAE     = 5.6219
# MAPE    = 2.39%
# R²      = 0.9664
# HitRate = 53.61%
# Sharpe  = 0.1362
