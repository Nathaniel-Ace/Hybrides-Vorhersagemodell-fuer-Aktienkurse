# %% [markdown]
# # GARCH + LSTM
# ## zusätzliche Features: RSI + Google Trends
#
# Zeitraum: 1.1.2015 bis 6.2.2025
#
# GTD: "NVIDIA stock", "sell NVIDIA stock", "buy NVIDIA stock" (alle drei Spalten)
#
# Google Trends waren ursprünglich monatlich --> wurden auf wöchentliche Werte interpoliert.

# %%
# %run ../src/GARCH_LSTM_RSI_GTD.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14', 'NVIDIA stock', 'sell NVIDIA stock', 'buy NVIDIA stock']
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.0731464778770559
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.001, 'batch_size': 16}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Fold 1: RMSE Log‐Renditen = 0.0668, RMSE Preise = 0.3566
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Fold 2: RMSE Log‐Renditen = 0.0670, RMSE Preise = 1.3685
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Fold 3: RMSE Log‐Renditen = 0.0953, RMSE Preise = 10.0167
#
# Durchschn. RMSE Log‑Renditen: 0.0764
# Durchschn. RMSE Aktienkurse: 3.9139

# %% [markdown]
# Im Vergleich zur vorherigen Version konnte durch Hyperparameter‑Optimierung eine leichte Verbesserung erreicht werden:
#
# - **Verwendete statische Features**: GARCH_vol, RSI_14 plus die drei Google‑Trends‑Spalten (“NVIDIA stock”, “sell NVIDIA stock”, “buy NVIDIA stock”).
# - **Bestes Setup** (aus 3‑fach‑CV): LSTM mit 50 Einheiten, Dropout 0.2, Lernrate 0.001, Batch‑Size 16.
# - **Fold‑Ergebnisse Log‑Renditen RMSE**: 0.0668, 0.0670, 0.0953 → Ø 0.0764
# - **Fold‑Ergebnisse Kurs‑RMSE**: 0.3566, 1.3685, 10.0167 → Ø 3.9139
#
# Die Vorhersagen folgen dem groben Trend sehr gut, insbesondere in ruhigeren Phasen (Fold 1 & 2), zeigen aber weiterhin Schwierigkeiten, auf starke Kurs‑Ausreißer im letzten Fold zu reagieren, was den höheren RMSE in volatilen Perioden erklärt.

# %% [markdown]
# # GARCH + LSTM
# ## zusätzliche Features: RSI + Google Trends
#
# Zeitraum: 24.2.2020 bis 17.2.2025
#
# kürzerer Zeitraum (~5 Jahre) ermöglichte das Importieren von Google Trends Daten in wöchentlicher Frequenz.

# %%
# %run ../src/GARCH_LSTM_RSI_GTD.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14', 'NVIDIA stock', 'sell NVIDIA stock', 'buy NVIDIA stock']
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.08027016936403904
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.0005, 'batch_size': 16}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# Fold 1: RMSE Log‐Renditen = 0.0787, RMSE Preise = 1.7666
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# Fold 2: RMSE Log‐Renditen = 0.0644, RMSE Preise = 2.0562
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# Fold 3: RMSE Log‐Renditen = 0.1070, RMSE Preise = 13.3094
#
# Durchschn. RMSE Log‑Renditen: 0.0833
# Durchschn. RMSE Aktienkurse: 5.7107

# %% [markdown]
# # GARCH + LSTM
# ## zusätzliche Features: RSI + Trend_Average + Trend_Smoothed
#
# Zeitraum: 1.1.2015 bis 6.2.2025
#
# Google Trends waren ursprünglich monatlich --> wurden auf wöchentliche Werte interpoliert.

# %%
# %run ../src/GARCH_LSTM_RSI_GTDtrends.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14', 'Trend_Average', 'Trend_Smoothed']
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.06935190214729038
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.0005, 'batch_size': 16}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Fold 1: RMSE Log‐Renditen = 0.0686, RMSE Preise = 0.3666
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step
# Fold 2: RMSE Log‐Renditen = 0.0636, RMSE Preise = 1.2883
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step
# Fold 3: RMSE Log‐Renditen = 0.0852, RMSE Preise = 8.7267
#
# Durchschn. RMSE Log‑Renditen: 0.0725
# Durchschn. RMSE Aktienkurse: 3.4605

# %% [markdown]
# # GARCH + LSTM
# ## zusätzliche Features: RSI
#
# Zeitraum: 1.1.2015 bis 6.2.2025

# %%
# %run ../src/GARCH_LSTM_RSI.py
# Out:
# Fold 1: X_train shape = (120, 12), X_test shape = (119, 12)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Fold 1 – RMSE Log‑Renditen: 0.0643, RMSE Preise: 0.3335
# Fold 2: X_train shape = (249, 12), X_test shape = (119, 12)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step
# Fold 2 – RMSE Log‑Renditen: 0.0567, RMSE Preise: 1.1167
# Fold 3: X_train shape = (378, 12), X_test shape = (119, 12)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Fold 3 – RMSE Log‑Renditen: 0.0613, RMSE Preise: 5.3604
#
# Durchschn. RMSE Log‑Renditen: 0.0608
# Durchschn. RMSE Aktienkurse:  2.2702

# %% [markdown]
# # GARCH + LSTM
# ## zusätzliche Features: RSI
# ## Version 3
#
# Zeitraum: 1.1.2015 bis 6.2.2025

# %%
# %run ../src/GARCH_LSTM_RSI2.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14']
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.06262983234601438
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.001, 'batch_size': 16}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Fold 1: RMSE Log‐Renditen = 0.0661, RMSE Preise = 0.3478
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Fold 2: RMSE Log‐Renditen = 0.0560, RMSE Preise = 1.1059
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Fold 3: RMSE Log‐Renditen = 0.0636, RMSE Preise = 5.7397
#
# Durchschn. RMSE Log‑Renditen: 0.0619
# Durchschn. RMSE Aktienkurse: 2.3978

# %% [markdown]
# # GARCH + LSTM
# ## zusätzliche Features: RSI + Google Trends
#
# Zeitraum: 29.12.2014 bis 14.04.2025
#
# GTD: "NVIDIA stock", "sell NVIDIA stock", "buy NVIDIA stock" (alle drei Spalten)
#
# wöchentliche Google Trends Daten wurden stückweise importiert um Rate-Limits zu umgehen

# %%
# %run ../src/GARCH_LSTM_RSI_GTD.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14', 'NVIDIA stock', 'sell NVIDIA stock', 'buy NVIDIA stock']
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DFF4DF9800> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %% [markdown]
# # GARCH + LSTM
# ## zusätzliche Features: RSI + Trend_Average + Trend_Smoothed
#
# Zeitraum: 29.12.2014 bis 14.04.2025
#
# wöchentliche Google Trends Daten wurden stückweise importiert um Rate-Limits zu umgehen

# %%
# %run ../src/GARCH_LSTM_RSI_GTDtrends.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14', 'Trend_Average', 'Trend_Smoothed']
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.0685560111110209
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.001, 'batch_size': 16}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Fold 1: RMSE Log‐Renditen = 0.0741, RMSE Preise = 0.4008
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Fold 2: RMSE Log‐Renditen = 0.0657, RMSE Preise = 1.2944
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Fold 3: RMSE Log‐Renditen = 0.0634, RMSE Preise = 5.8402
#
# Durchschn. RMSE Log‑Renditen: 0.0678
# Durchschn. RMSE Aktienkurse: 2.5118

# %% [markdown]
# # GARCH + LSTM
# ## zusätzliche Features: RSI
#
# Zeitraum: 01.01.2015 bis 24.04.2025

# %%
# %run ../src/GARCH_LSTM_RSI2.py
# Out:
# Verwendete statische Features (RSI + GARCH): ['GARCH_vol', 'RSI_14']
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.06093179358823481
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.001, 'batch_size': 16}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Fold 1: RMSE Log‐Renditen = 0.0676, RMSE Preise = 0.3633
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Fold 2: RMSE Log‐Renditen = 0.0600, RMSE Preise = 1.1421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Fold 3: RMSE Log‐Renditen = 0.0609, RMSE Preise = 5.6915
#
# Durchschn. RMSE Log‑Renditen: 0.0628
# Durchschn. RMSE Aktienkurse: 2.3990
