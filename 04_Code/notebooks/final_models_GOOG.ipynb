# %% [markdown]
# # LSTM-Modell

# %%
# %run ../src/lstm.py
# Out:
# Fold 1 – RMSE=3.2970, MAE=2.5936, MAPE=4.50%, R²=0.6742, Hit-Rate=56.1%, Sharpe=0.4231
# WARNING:tensorflow:5 out of the last 5 calls to <function predict_fn at 0x00000243D723DD00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Fold 2 – RMSE=8.0193, MAE=6.7014, MAPE=6.09%, R²=0.8909, Hit-Rate=50.4%, Sharpe=0.4105
# WARNING:tensorflow:6 out of the last 6 calls to <function predict_fn at 0x00000243D98FC180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Fold 3 – RMSE=17.0336, MAE=14.2410, MAPE=9.37%, R²=0.6815, Hit-Rate=48.8%, Sharpe=0.4264
#
# === Durchschnitt aller Folds ===
# RMSE:     9.4500
# MAE:      7.8453
# MAPE:     6.6523%
# R²:       0.7489
# Hit-Rate: 51.7615%
# Sharpe:   0.4200

# %% [markdown]
# # XGBoost-Modell

# %%
# %run ../src/XGBoost.py
# Out:
# Fold 1: X_train=(127, 10), y_train=(127,), X_test=(124, 10), y_test=(124,)
# Fold 1 – RMSE=12.7795, MAE=11.3960, MAPE=18.92%, R²=-3.8947, Hit-Rate=1.6%, Sharpe=-0.0197
#
# Fold 2: X_train=(261, 10), y_train=(261,), X_test=(124, 10), y_test=(124,)
# Fold 2 – RMSE=52.7558, MAE=46.4952, MAPE=38.26%, R²=-3.7233, Hit-Rate=4.9%, Sharpe=-0.0675
#
# Fold 3: X_train=(395, 10), y_train=(395,), X_test=(124, 10), y_test=(124,)
# Fold 3 – RMSE=24.6164, MAE=17.5907, MAPE=10.56%, R²=0.3349, Hit-Rate=30.9%, Sharpe=0.0983
#
# === Durchschnitt über alle Folds ===
# RMSE:       30.0505
# MAE:        25.1606
# MAPE:       22.5825%
# R²:         -2.4277
# Hit-Rate:   12.4661%
# Sharpe:     0.0037

# %% [markdown]
# # GARCH + LSTM Hybridmodell

# %%
# %run ../src/GARCH_LSTM2.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Fold 1 fertig.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Fold 2 fertig.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Fold 3 fertig.
# === Log-Returns (Ø über 3 Folds) ===
# RMSE: 0.0375, MAE: 0.0284, MAPE: 111.7048%, R²: -0.0207, Hit: 68.2927%, Sharpe: 0.0093
# === Close-Preise (Ø über 3 Folds) ===
# RMSE: 3.9732, MAE: 3.0042, MAPE: 2.8353%, R²: 0.9342, Hit: 48.5095%, Sharpe: 0.1120

# %% [markdown]
# # GARCH + LSTM Hybridmodell
# ## zusätzliches Feature: RSI

# %%
# %run ../src/GARCH_LSTM_RSI2.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.0344
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.0005, 'batch_size': 16}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Fold 1:
#   Returns → RMSE=0.0369, MAE=0.0258, MAPE=164.9156%, R2=0.0396, Hit-Rate=67.5000%, Sharpe=0.0919
#   Prices  → RMSE=2.1853, MAE=1.5145, MAPE=2.6238%, R2=0.8484, Hit-Rate=53.3333%, Sharpe=0.0617
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Fold 2:
#   Returns → RMSE=0.0369, MAE=0.0284, MAPE=166.6387%, R2=0.2367, Hit-Rate=71.6667%, Sharpe=-0.1785
#   Prices  → RMSE=4.0936, MAE=3.1645, MAPE=2.8298%, R2=0.9682, Hit-Rate=50.8333%, Sharpe=0.0815
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Fold 3:
#   Returns → RMSE=0.0311, MAE=0.0240, MAPE=127.9339%, R2=0.1769, Hit-Rate=75.8333%, Sharpe=0.0542
#   Prices  → RMSE=4.4668, MAE=3.4349, MAPE=2.3873%, R2=0.9765, Hit-Rate=56.6667%, Sharpe=0.1549
#
# === Durchschnittliche Metriken: Log-Renditen ===
# RMSE      = 0.0350
# MAE       = 0.0261
# MAPE      = 153.16%
# R²        = 0.1510
# HitRate   = 71.67%
# Sharpe    = -0.0108
#
# === Durchschnittliche Metriken: Preise ===
# RMSE      = 3.5819
# MAE       = 2.7047
# MAPE      = 2.61%
# R²        = 0.9310
# HitRate   = 53.61%
# Sharpe    = 0.0994

# %% [markdown]
# # GARCH + XGBoost Hybridmodell

# %%
# %run ../src/GARCH_XGBoost2.py
# Out:
# Fold 1: RMSE_Returns=0.0387, RMSE_Prices=2.2698
# Fold 2: RMSE_Returns=0.0451, RMSE_Prices=4.9761
# Fold 3: RMSE_Returns=0.0395, RMSE_Prices=6.0316
#
# === Ø Metriken: Log-Renditen ===
# RMSE   = 0.0411
# MAE    = 0.0312
# MAPE   = 161.82%
# R²     = -0.2283
# HitRate= 52.96%
# Sharpe = 0.1216
#
# === Ø Metriken: Close-Preise ===
# RMSE   = 4.4258
# MAE    = 3.2944
# MAPE   = 3.12%
# R²     = 0.9212
# HitRate= 47.97%
# Sharpe = 0.0671

# %% [markdown]
# # GARCH + XGBoost Hybridmodell
# ## zusätzliches Feature: RSI

# %%
# %run ../src/GARCH_XGBoost_RSI.py
# Out:
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: RMSE_Returns=0.0363, RMSE_Prices=2.1304
# Fold 2: RMSE_Returns=0.0400, RMSE_Prices=4.4089
# Fold 3: RMSE_Returns=0.0326, RMSE_Prices=4.8467
#
# === Ø Metriken: Log-Renditen ===
# RMSE    = 0.0363
# MAE     = 0.0272
# MAPE    = 124.28%
# R²      = 0.0909
# HitRate = 62.53%
# Sharpe  = 0.2745
#
# === Ø Metriken: Close-Preise ===
# RMSE    = 3.7953
# MAE     = 2.8616
# MAPE    = 2.73%
# R²      = 0.9304
# HitRate = 54.17%
# Sharpe  = 0.0653

# %% [markdown]
# # GARCH + LSTM Hybridmodell
# ## zusätzliches Feature: RSI & GTD

# %%
# %run ../src/GARCH_LSTM_RSI_GTD.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14', 'Google stock', 'sell Google stock', 'buy Google stock']
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E42E659080> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E42E659080> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
#
# Best CV-RMSE (Log-Renditen): 0.0377
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.001, 'batch_size': 16}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Fold 1:
#   Returns → RMSE=0.0559, MAE=0.0503, MAPE=506.79%, R²=-1.1977, Hit-Rate=46.7%, Sharpe=0.0351
#   Prices  → RMSE=3.2125, MAE=2.8783, MAPE=4.90%, R²=0.6740, Hit-Rate=50.8%, Sharpe=0.0474
#
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Fold 2:
#   Returns → RMSE=0.0876, MAE=0.0782, MAPE=750.96%, R²=-3.3763, Hit-Rate=52.5%, Sharpe=0.0365
#   Prices  → RMSE=9.5357, MAE=8.4321, MAPE=7.45%, R²=0.8310, Hit-Rate=48.3%, Sharpe=0.0823
#
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Fold 3:
#   Returns → RMSE=0.0406, MAE=0.0329, MAPE=184.04%, R²=-0.4024, Hit-Rate=64.2%, Sharpe=0.0009
#   Prices  → RMSE=5.8992, MAE=4.7192, MAPE=3.23%, R²=0.9602, Hit-Rate=46.7%, Sharpe=0.1599
#
#
# === Durchschnittliche Metriken: Log-Renditen ===
# RMSE    = 0.0614
# MAE     = 0.0538
# MAPE    = 480.59%
# R²      = -1.6588
# HitRate = 54.44%
# Sharpe  = 0.0241
#
# === Durchschnittliche Metriken: Preise ===
# RMSE    = 6.2158
# MAE     = 5.3432
# MAPE    = 5.19%
# R²      = 0.8217
# HitRate = 48.61%
# Sharpe  = 0.0966

# %% [markdown]
# # GARCH + XGBoost Hybridmodell
# ## zusätzliches Feature: RSI & GTD

# %%
# %run ../src/GARCH_XGBoost_RSI_GTD.py
# Out:
# Verwendete statische Features (GTD + RSI + GARCH): ['GARCH_vol', 'RSI_14', 'Google stock', 'sell Google stock', 'buy Google stock']
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: X_train=(121, 15), X_test=(121, 15)
# Fold 1:
#   Returns → RMSE=0.0355, MAE=0.0257, MAPE=114.32%, R²=0.1112, Hit-Rate=63.3%, Sharpe=-0.0763
#   Prices  → RMSE=2.0821, MAE=1.4903, MAPE=2.59%, R²=0.8630, Hit-Rate=55.0%, Sharpe=0.0464
#
# Fold 2: X_train=(252, 15), X_test=(121, 15)
# Fold 2:
#   Returns → RMSE=0.0398, MAE=0.0298, MAPE=148.79%, R²=0.0958, Hit-Rate=67.5%, Sharpe=-0.0610
#   Prices  → RMSE=4.4265, MAE=3.3101, MAPE=2.99%, R²=0.9636, Hit-Rate=51.7%, Sharpe=0.0782
#
# Fold 3: X_train=(383, 15), X_test=(121, 15)
# Fold 3:
#   Returns → RMSE=0.0314, MAE=0.0250, MAPE=137.58%, R²=0.1583, Hit-Rate=69.2%, Sharpe=0.0850
#   Prices  → RMSE=4.5556, MAE=3.5921, MAPE=2.48%, R²=0.9763, Hit-Rate=51.7%, Sharpe=0.1599
#
#
# === Durchschnittliche Metriken: Log-Renditen ===
# RMSE    = 0.0356
# MAE     = 0.0268
# MAPE    = 133.56%
# R²      = 0.1218
# HitRate = 66.67%
# Sharpe  = -0.0175
#
# === Durchschnittliche Metriken: Preise ===
# RMSE    = 3.6881
# MAE     = 2.7975
# MAPE    = 2.68%
# R²      = 0.9343
# HitRate = 52.78%
# Sharpe  = 0.0948
