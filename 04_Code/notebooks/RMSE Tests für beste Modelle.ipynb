# %% [markdown]
# # GARCH + LSTM mit RSI
# ## NVDA

# %%
# %run ../src/GARCH_LSTM_RSI2.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.0616
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0043
# Epoch 2/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043
# Epoch 3/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039
# Epoch 4/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036
# Epoch 5/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033
# Epoch 6/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038
# Epoch 7/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031
# Epoch 8/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034
# Epoch 9/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034
# Epoch 10/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032
# Epoch 11/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033
# Epoch 12/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032
# Epoch 13/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035
# Epoch 14/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035
# Epoch 15/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031
# Epoch 16/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033
# Epoch 17/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035
# Epoch 18/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032
# Epoch 19/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036
# Epoch 20/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📈 RMSE (Renditeebene) auf Trainingsdaten: 0.0560
# 💰 RMSE (Preisebene) auf Trainingsdaten:  2.7003
# ✅ Finales Modell gespeichert
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Fold 1:
#   Returns → RMSE=0.0677, MAE=0.0472, MAPE=382.2126%, R2=0.0534, Hit-Rate=69.1667%, Sharpe=0.0084
#   Prices  → RMSE=0.3632, MAE=0.2448, MAPE=4.8128%, R2=0.8930, Hit-Rate=56.6667%, Sharpe=0.0814
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Fold 2:
#   Returns → RMSE=0.0572, MAE=0.0449, MAPE=464.8026%, R2=0.2861, Hit-Rate=80.8333%, Sharpe=0.0198
#   Prices  → RMSE=1.0976, MAE=0.8250, MAPE=4.4930%, R2=0.9614, Hit-Rate=57.5000%, Sharpe=0.0587
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Fold 3:
#   Returns → RMSE=0.0611, MAE=0.0475, MAPE=157.2595%, R2=0.2342, Hit-Rate=78.3333%, Sharpe=-0.1111
#   Prices  → RMSE=5.4830, MAE=3.7670, MAPE=4.6860%, R2=0.9832, Hit-Rate=60.8333%, Sharpe=0.2739
#
# === Durchschnittliche Metriken: Log-Renditen ===
# RMSE      = 0.0620
# MAE       = 0.0465
# MAPE      = 334.7582%
# R²        = 0.1913
# HitRate   = 76.1111%
# Sharpe    = -0.0276
#
# === Durchschnittliche Metriken: Preise ===
# RMSE      = 2.3146
# MAE       = 1.6123
# MAPE      = 4.6639%
# R²        = 0.9459
# HitRate   = 58.3333%
# Sharpe    = 0.1380

# %% [markdown]
# # RMSE Tests auf folgende Zeitperioden:
# ## letzter Tag, letzte Woche, letzten 30 Tage
# ## NVDA

# %%
# %run ../src/GARCH_LSTM_RSI_RMSE_Test.py
# Out:
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\04_Code\src\GARCH_LSTM_RSI_RMSE_Test.py:12: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   df = df.last("30D").copy()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
#
# RMSE auf den letzten 30 Tagen:
# Letzter Tag    : 0.0404
# Letzte Woche   : 0.0261
# Letzte 30 Tage : 0.0232
#
# RMSE auf den tatsächlichen Aktienkursen:
# Letzter Tag    : 5.5864
# Letzte Woche   : 3.3170
# Letzte 30 Tage : 2.9196

# %% [markdown]
# # GARCH + XGBoost mit RSI
# ## NVDA

# %%
# %run ../src/GARCH_XGBoost_RSI.py
# Out:
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: RMSE_Returns=0.0691, RMSE_Prices=0.3612
# Fold 2: RMSE_Returns=0.0625, RMSE_Prices=1.2260
# Fold 3: RMSE_Returns=0.0634, RMSE_Prices=5.8687
#
# === Ø Metriken: Log-Renditen ===
# RMSE    = 0.0650
# MAE     = 0.0501
# MAPE    = 386.94%
# R²      = 0.1113
# HitRate = 60.88%
# Sharpe  = 0.3458
#
# === Ø Metriken: Close-Preise ===
# RMSE    = 2.4853
# MAE     = 1.7574
# MAPE    = 5.04%
# R²      = 0.9422
# HitRate = 53.06%
# Sharpe  = 0.0573
# 📈 RMSE (Renditeebene) auf Trainingsdaten: 0.0493
# 💰 RMSE (Preisebene) auf Trainingsdaten:  2.3607
# ✅ Modell gespeichert: ../../05_Modelle/garch_xgboost_nvda_final_model.joblib

# %% [markdown]
# # RMSE Tests auf folgende Zeitperioden:
# ## letzter Tag, letzte Woche, letzten 30 Tage
# ## NVDA

# %%
# %run ../src/GARCH_XGBoost_RSI_RMSE_Test.py
# Out:
# ✅ Modell geladen: ../../05_Modelle/garch_xgboost_nvda_final_model.joblib
#
# 📈 RMSE auf Log-Renditen (Out-of-sample)
# Letzter Tag    : 0.0170
# Letzte Woche   : 0.0323
# Letzte 30 Tage : 0.0335
#
# 💰 RMSE auf Preisen (Out-of-sample)
# Letzter Tag    : 2.2831
# Letzte Woche   : 3.8847
# Letzte 30 Tage : 3.8907

# %% [markdown]
# # GARCH + LSTM mit RSI
# ## GOOG

# %%
# %run ../src/GARCH_LSTM_RSI2.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000231732FDA80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000231732FDA80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.0352
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0015
# Epoch 2/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 3/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 4/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 5/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 6/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 7/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 8/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 9/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 10/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010
# Epoch 11/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5779e-04
# Epoch 12/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 13/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8232e-04
# Epoch 14/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4660e-04
# Epoch 15/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 16/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 17/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 18/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9414e-04
# Epoch 19/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9765e-04
# Epoch 20/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
# 📈 RMSE (Renditeebene) auf Trainingsdaten: 0.0310
# 💰 RMSE (Preisebene) auf Trainingsdaten:  3.1785
# ✅ Finales Modell gespeichert
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Fold 1:
#   Returns → RMSE=0.0359, MAE=0.0256, MAPE=146.3000%, R2=0.0937, Hit-Rate=66.6667%, Sharpe=-0.0997
#   Prices  → RMSE=2.1165, MAE=1.4976, MAPE=2.5911%, R2=0.8578, Hit-Rate=53.3333%, Sharpe=0.0623
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Fold 2:
#   Returns → RMSE=0.0386, MAE=0.0297, MAPE=154.1063%, R2=0.1655, Hit-Rate=73.3333%, Sharpe=0.0802
#   Prices  → RMSE=4.2901, MAE=3.3083, MAPE=2.9695%, R2=0.9651, Hit-Rate=48.3333%, Sharpe=0.0822
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Fold 3:
#   Returns → RMSE=0.0310, MAE=0.0243, MAPE=131.4083%, R2=0.1857, Hit-Rate=75.0000%, Sharpe=-0.0028
#   Prices  → RMSE=4.4929, MAE=3.4914, MAPE=2.4204%, R2=0.9762, Hit-Rate=53.3333%, Sharpe=0.1547
#
# === Durchschnittliche Metriken: Log-Renditen ===
# RMSE      = 0.0351
# MAE       = 0.0265
# MAPE      = 143.9382%
# R²        = 0.1483
# HitRate   = 71.6667%
# Sharpe    = -0.0074
#
# === Durchschnittliche Metriken: Preise ===
# RMSE      = 3.6332
# MAE       = 2.7658
# MAPE      = 2.6603%
# R²        = 0.9330
# HitRate   = 51.6667%
# Sharpe    = 0.0997

# %% [markdown]
# # RMSE Tests auf folgende Zeitperioden:
# ## letzter Tag, letzte Woche, letzten 30 Tage
# ## GOOG

# %%
# %run ../src/GARCH_LSTM_RSI_RMSE_Test.py
# Out:
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\04_Code\src\GARCH_LSTM_RSI_RMSE_Test.py:13: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   df = df.last("30D").copy()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
#
# RMSE auf den letzten 30 Tagen:
# Letzter Tag    : 0.0014
# Letzte Woche   : 0.0266
# Letzte 30 Tage : 0.0238
#
# RMSE auf den tatsächlichen Aktienkursen:
# Letzter Tag    : 0.2418
# Letzte Woche   : 4.2228
# Letzte 30 Tage : 3.8107

# %% [markdown]
# # GARCH + XGBoost mit RSI
# ## GOOG

# %%
# %run ../src/GARCH_XGBoost_RSI.py
# Out:
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: RMSE_Returns=0.0363, RMSE_Prices=2.1304
# Fold 2: RMSE_Returns=0.0400, RMSE_Prices=4.4089
# Fold 3: RMSE_Returns=0.0326, RMSE_Prices=4.8467
#
# === Ø Metriken: Log-Renditen ===
# RMSE    = 0.0363
# MAE     = 0.0272
# MAPE    = 124.28%
# R²      = 0.0909
# HitRate = 62.53%
# Sharpe  = 0.2745
#
# === Ø Metriken: Close-Preise ===
# RMSE    = 3.7953
# MAE     = 2.8616
# MAPE    = 2.73%
# R²      = 0.9304
# HitRate = 54.17%
# Sharpe  = 0.0653
# 📈 RMSE (Renditeebene) auf Trainingsdaten: 0.0314
# 💰 RMSE (Preisebene) auf Trainingsdaten:  3.1706
# ✅ Modell gespeichert: ../../05_Modelle/garch_xgboost_goog_final_model.joblib

# %% [markdown]
# # RMSE Tests auf folgende Zeitperioden:
# ## letzter Tag, letzte Woche, letzten 30 Tage
# ## GOOG

# %%
# %run ../src/GARCH_XGBoost_RSI_RMSE_Test.py
# Out:
# ✅ Modell geladen: ../../05_Modelle/garch_xgboost_goog_final_model.joblib
#
# 📈 RMSE auf Log-Renditen (Out-of-sample)
# Letzter Tag    : 0.0383
# Letzte Woche   : 0.0293
# Letzte 30 Tage : 0.0255
#
# 💰 RMSE auf Preisen (Out-of-sample)
# Letzter Tag    : 6.2649
# Letzte Woche   : 4.6420
# Letzte 30 Tage : 4.0512

# %% [markdown]
# # GARCH + LSTM mit RSI
# ## MSFT

# %%
# %run ../src/GARCH_LSTM_RSI2.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
#
# Best CV‑RMSE (Log‑Renditen): 0.0283
# Best Config: {'units': 50, 'dropout': 0.2, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.5647e-04
# Epoch 2/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5902e-04
# Epoch 3/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3975e-04
# Epoch 4/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9079e-04
# Epoch 5/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6838e-04
# Epoch 6/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0273e-04
# Epoch 7/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1447e-04
# Epoch 8/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7118e-04
# Epoch 9/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4765e-04
# Epoch 10/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5680e-04
# Epoch 11/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6445e-04
# Epoch 12/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2928e-04
# Epoch 13/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1102e-04
# Epoch 14/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1674e-04
# Epoch 15/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7391e-04
# Epoch 16/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1999e-04
# Epoch 17/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7972e-04
# Epoch 18/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7150e-04
# Epoch 19/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0574e-04
# Epoch 20/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6054e-04
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📈 RMSE (Renditeebene) auf Trainingsdaten: 0.0264
# 💰 RMSE (Preisebene) auf Trainingsdaten:  6.2498
# ✅ Finales Modell gespeichert
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Fold 1:
#   Returns → RMSE=0.0307, MAE=0.0222, MAPE=286.9707%, R2=0.1218, Hit-Rate=76.6667%, Sharpe=-0.0428
#   Prices  → RMSE=3.8401, MAE=2.6001, MAPE=2.2414%, R2=0.9758, Hit-Rate=53.3333%, Sharpe=0.2097
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Fold 2:
#   Returns → RMSE=0.0303, MAE=0.0248, MAPE=211.7713%, R2=0.2851, Hit-Rate=75.0000%, Sharpe=-0.1009
#   Prices  → RMSE=7.5756, MAE=6.2088, MAPE=2.4854%, R2=0.9607, Hit-Rate=59.1667%, Sharpe=0.0505
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Fold 3:
#   Returns → RMSE=0.0259, MAE=0.0212, MAPE=200.5089%, R2=0.0788, Hit-Rate=72.5000%, Sharpe=0.1278
#   Prices  → RMSE=9.5095, MAE=7.7285, MAPE=2.0999%, R2=0.9744, Hit-Rate=60.0000%, Sharpe=0.1655
#
# === Durchschnittliche Metriken: Log-Renditen ===
# RMSE      = 0.0290
# MAE       = 0.0227
# MAPE      = 233.0837%
# R²        = 0.1619
# HitRate   = 74.7222%
# Sharpe    = -0.0053
#
# === Durchschnittliche Metriken: Preise ===
# RMSE      = 6.9751
# MAE       = 5.5125
# MAPE      = 2.2756%
# R²        = 0.9703
# HitRate   = 57.5000%
# Sharpe    = 0.1419

# %% [markdown]
# # RMSE Tests auf folgende Zeitperioden:
# ## letzter Tag, letzte Woche, letzten 30 Tage
# ## MSFT

# %%
# %run ../src/GARCH_LSTM_RSI_RMSE_Test.py
# Out:
# C:\Users\natha\OneDrive\Desktop\Bachelor Arbeit\Bachelor-Arbeit\04_Code\src\GARCH_LSTM_RSI_RMSE_Test.py:13: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   df = df.last("30D").copy()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
#
# RMSE auf den letzten 30 Tagen:
# Letzter Tag    : 0.0039
# Letzte Woche   : 0.0092
# Letzte 30 Tage : 0.0215
#
# RMSE auf den tatsächlichen Aktienkursen:
# Letzter Tag    : 1.7823
# Letzte Woche   : 4.0851
# Letzte 30 Tage : 8.9859

# %% [markdown]
# # GARCH + XGBoost mit RSI
# ## MSFT

# %%
# %run ../src/GARCH_XGBoost_RSI.py
# Out:
# >>> Best XGBoost Params: {'subsample': 0.8, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 1.0}
# Fold 1: RMSE_Returns=0.0330, RMSE_Prices=4.1109
# Fold 2: RMSE_Returns=0.0340, RMSE_Prices=8.6302
# Fold 3: RMSE_Returns=0.0250, RMSE_Prices=9.1455
#
# === Ø Metriken: Log-Renditen ===
# RMSE    = 0.0307
# MAE     = 0.0243
# MAPE    = 177.56%
# R²      = 0.0760
# HitRate = 63.36%
# Sharpe  = 0.4877
#
# === Ø Metriken: Close-Preise ===
# RMSE    = 7.2955
# MAE     = 5.7848
# MAPE    = 2.43%
# R²      = 0.9659
# HitRate = 53.06%
# Sharpe  = 0.1070
# 📈 RMSE (Renditeebene) auf Trainingsdaten: 0.0265
# 💰 RMSE (Preisebene) auf Trainingsdaten:  6.0458
# ✅ Modell gespeichert: ../../05_Modelle/garch_xgboost_msft_final_model.joblib

# %% [markdown]
# # RMSE Tests auf folgende Zeitperioden:
# ## letzter Tag, letzte Woche, letzten 30 Tage
# ## MSFT

# %%
# %run ../src/GARCH_XGBoost_RSI_RMSE_Test.py
# Out:
# ✅ Modell geladen: ../../05_Modelle/garch_xgboost_msft_final_model.joblib
#
# 📈 RMSE auf Log-Renditen (Out-of-sample)
# Letzter Tag    : 0.0021
# Letzte Woche   : 0.0088
# Letzte 30 Tage : 0.0229
#
# 💰 RMSE auf Preisen (Out-of-sample)
# Letzter Tag    : 0.9393
# Letzte Woche   : 3.8803
# Letzte 30 Tage : 9.5051
