# %% [markdown]
# # LSTM

# %%
# %run ../src/lstm.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Fold 1 RMSE: 3.0187
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Fold 2 RMSE: 7.8536
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000204968F1DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000204968F1DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Fold 3 RMSE: 10.4705
#
# Durchschnittlicher RMSE über 3 Folds: 7.1142

# %% [markdown]
# # XGBoost

# %%
# %run ../src/XGBoost.py
# Out:
# Fold 1: X_train=(125, 10), y_train=(125,), X_test=(122, 10), y_test=(122,)
# Fold 1 RMSE: 12.7542
# Fold 2: X_train=(257, 10), y_train=(257,), X_test=(122, 10), y_test=(122,)
# Fold 2 RMSE: 44.2022
# Fold 3: X_train=(389, 10), y_train=(389,), X_test=(122, 10), y_test=(122,)
# Fold 3 RMSE: 23.6211
#
# Durchschnittlicher RMSE über 3 Folds: 26.8592

# %% [markdown]
# # 1. Hybrid-Modell: GARCH + XGBoost

# %%
# %run ../src/GARCH_XGBoost.py
# Out:
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.002
# Vol Model:                      GARCH   Log-Likelihood:               -163.587
# Distribution:                  Normal   AIC:                           333.175
# Method:            Maximum Likelihood   BIC:                           345.324
#                                         No. Observations:                  424
# Date:                Fri, Apr 04 2025   Df Residuals:                      424
# Time:                        10:24:41   Df Model:                            0
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.0234  2.146e-02      1.092      0.275 [-1.863e-02,6.549e-02]
# alpha[1]       0.1811      0.127      1.423      0.155   [-6.832e-02,  0.431]
# beta[1]        0.6601      0.241      2.736  6.223e-03      [  0.187,  1.133]
# =============================================================================
#
# Covariance estimator: robust
# X_train shape: (414, 11) y_train shape: (414,)
# X_test shape: (96, 11) y_test shape: (96,)
# RMSE auf logarithmische Renditen: 0.0396
# RMSE auf Aktienkurs-Basis: 6.2616

# %% [markdown]
# # 2. Hybrid-Modell: GARCH + LSTM

# %%
# %run ../src/GARCH_LSTM2.py
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Fold 1 RMSE auf log-Renditen: 0.0331
# Fold 1 RMSE auf Aktienkurs-Basis: 1.8910
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Fold 2 RMSE auf log-Renditen: 0.0410
# Fold 2 RMSE auf Aktienkurs-Basis: 4.5525
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Fold 3 RMSE auf log-Renditen: 0.0362
# Fold 3 RMSE auf Aktienkurs-Basis: 5.2297
# Durchschnittlicher RMSE auf log-Renditen über 3 Folds: 0.0368
# Durchschnittlicher RMSE auf Aktienkurs-Basis über 3 Folds: 3.8911
